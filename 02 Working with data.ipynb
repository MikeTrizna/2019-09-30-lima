# %%
import antigravity

# %%
import pandas as pd

# %%
survey_df = pd.read_csv("https://ndownloader.figshare.com/files/2292172")

# %%
type(survey_df)
# Out:
# pandas.core.frame.DataFrame

# %%
survey_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
survey_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
survey_df.head(2)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
#
#    weight
# 0     NaN
# 1     NaN

# %%
survey_df['year'].tail()
# Out:
# 35544    2002
# 35545    2002
# 35546    2002
# 35547    2002
# 35548    2002
# Name: year, dtype: int64

# %%
survey_df.iloc[0:3,4]
# Out:
# 0    2
# 1    3
# 2    2
# Name: plot_id, dtype: int64

# %% [markdown]
# ## Filtering

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35549 entries, 0 to 35548
# Data columns (total 9 columns):
# record_id          35549 non-null int64
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.4+ MB

# %%
survey_df['year'] > 1990
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 35519     True
# 35520     True
# 35521     True
# 35522     True
# 35523     True
# 35524     True
# 35525     True
# 35526     True
# 35527     True
# 35528     True
# 35529     True
# 35530     True
# 35531     True
# 35532     True
# 35533     True
# 35534     True
# 35535     True
# 35536     True
# 35537     True
# 35538     True
# 35539     True
# 35540     True
# 35541     True
# 35542     True
# 35543     True
# 35544     True
# 35545     True
# ...

# %%
survey_df[survey_df['year'] > 1990].sample(10)
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 33396      33397      2    9  2002        1         RO   M             17.0
# 26873      26874      9   28  1997       10         PM   M             20.0
# 26854      26855      9   27  1997       19         PB   M             26.0
# 26605      26606      7   29  1997        7         PP   F             22.0
# 32512      32513      8   26  2001        6         OT   M             20.0
# 33700      33701      3   14  2002        8         PB   F             26.0
# 21619      21620      6   14  1994       18         PP   F             21.0
# 35059      35060     11    9  2002       20         PB   M             27.0
# 18691      18692      5   14  1991        3         OL   F             20.0
# 18199      18200      1   11  1991       24         PE   M             21.0
#
#        weight
# 33396     8.0
# 26873    15.0
# 26854    43.0
# 26605    23.0
# 32512    21.0
# 33700    37.0
# 21619    19.0
# ...

# %%
survey_df[survey_df['year'] > 1990]['plot_id'].sample(10)
# Out:
# 24146    14
# 23262    22
# 32382     2
# 35216    17
# 23463    16
# 18392     9
# 21093    17
# 25236    18
# 23329     6
# 26319    12
# Name: plot_id, dtype: int64

# %%
after_1990 = survey_df['year'] > 1990
just_males = survey_df['sex'] == 'M'

survey_df[after_1990 & just_males].head()
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 18190      18191      1   11  1991       12         OL   M             21.0
# 18194      18195      1   11  1991       21         RM   M             16.0
# 18195      18196      1   11  1991        1         DM   M             37.0
# 18197      18198      1   11  1991       12         OL   M             21.0
# 18199      18200      1   11  1991       24         PE   M             21.0
#
#        weight
# 18190    31.0
# 18194    11.0
# 18195    43.0
# 18197    32.0
# 18199    21.0

# %%
len(survey_df[after_1990 & just_males])
# Out:
# 8452

# %%
len(survey_df[after_1990 | just_males])
# Out:
# 26256

# %%
survey_df = survey_df.rename(columns = {'weight':'weight_g'})
survey_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight_g
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
survey_df['weight_kg'] = survey_df['weight_g'] / 1000
survey_df.sample(5)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 25531      25532      4   12  1997       20         PE    M             19.0
# 2478        2479      2   25  1980       11         DS    M             51.0
# 14196      14197      3   20  1988       18         AH  NaN              NaN
# 30953      30954      7    1  2000       21         PB    F             24.0
# 13308      13309      8   26  1987        2         PE    M             14.0
#
#        weight_g  weight_kg
# 25531      16.0      0.016
# 2478      143.0      0.143
# 14196       NaN        NaN
# 30953      30.0      0.030
# 13308      19.0      0.019

# %%
survey_df.sort_values('weight_g').head()
# Out:
#       record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 9908       9909      1   20  1985       15         RM    F             15.0
# 4289       4290      4    6  1981        4         PF  NaN              NaN
# 9793       9794      1   19  1985       24         RM    M             16.0
# 9789       9790      1   19  1985       16         RM    F             16.0
# 5345       5346      2   22  1982       21         PF    F             14.0
#
#       weight_g  weight_kg
# 9908       4.0      0.004
# 4289       4.0      0.004
# 9793       4.0      0.004
# 9789       4.0      0.004
# 5345       4.0      0.004

# %%
survey_df.sort_values('weight_g', ascending=False).head()
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 33048      33049     11   17  2001       12         NL   M             33.0
# 12870      12871      5   28  1987        2         NL   M             32.0
# 15458      15459      1   11  1989        9         NL   M             36.0
# 2132        2133     10   25  1979        2         NL   F             33.0
# 12728      12729      4   26  1987        2         NL   M             32.0
#
#        weight_g  weight_kg
# 33048     280.0      0.280
# 12870     278.0      0.278
# 15458     275.0      0.275
# 2132      274.0      0.274
# 12728     270.0      0.270

# %%
just_females=survey_df['sex']=='F'

# %%
survey_df[just_females].sort_values('hindfoot_length', ascending=False).head(10)
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 30424      30425      3    4  2000        1         DO   F             64.0
# 1693        1694      3   31  1979        8         DS   F             58.0
# 4448        4449      5    4  1981        2         DS   F             57.0
# 4513        4514      6    4  1981        2         DS   F             55.0
# 17997      17998     11   10  1990       22         DS   F             55.0
# 3969        3970      3    9  1981        3         DS   F             54.0
# 3268        3269      9    7  1980       20         DS   F             54.0
# 10697      10698      8   20  1985        1         DS   F             54.0
# 13958      13959      1   24  1988        9         DS   F             54.0
# 4457        4458      5    4  1981        4         DS   F             54.0
#
#        weight_g  weight_kg
# 30424      35.0      0.035
# 1693      123.0      0.123
# 4448      136.0      0.136
# ...

# %%
longest_females = survey_df[just_females].sort_values('hindfoot_length', ascending=False).head(10)

# %%
longest_females.to_csv('longest_females.csv', index=False)
